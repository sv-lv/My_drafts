# %% [markdown]
# # Draft
# ## lesson 1
# *hgfd*
#
# [about matplotlib](https://habr.com/ru/post/468295/)
# $$x=\sqrt(y-5)$$

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Yes': [20, 40], 'No': [3,10]}, index=['first', 'second'])
df
# Out:
#         Yes  No
# first    20   3
# second   40  10

# %% [markdown]
# Магические команды

# %%
# %%time
import time
time.sleep(2)
# Out:
# Wall time: 2 s

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1, 2, 3], [1, 4, 9])

# %%
# %prun
plt.plot([1, 2, 3], [1, 4, 9])

# %% [markdown]
# Подключение библиотеки

# %%
# !python -m pip install pyautogui
